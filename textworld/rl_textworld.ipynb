# %%
# !pip install tatsu==5.8.3 textworld==1.6.1 gym torch torchvision torchaudio
# Out:
# Requirement already satisfied: tatsu==5.8.3 in /usr/local/lib/python3.12/dist-packages (5.8.3)
# Requirement already satisfied: textworld==1.6.1 in /usr/local/lib/python3.12/dist-packages (1.6.1)
# Requirement already satisfied: gym in /usr/local/lib/python3.12/dist-packages (0.25.2)
# Requirement already satisfied: torch in /usr/local/lib/python3.12/dist-packages (2.9.0+cpu)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.12/dist-packages (0.24.0+cpu)
# Requirement already satisfied: torchaudio in /usr/local/lib/python3.12/dist-packages (2.9.0+cpu)
# Requirement already satisfied: numpy>=1.14.5 in /usr/local/lib/python3.12/dist-packages (from textworld==1.6.1) (2.0.2)
# Requirement already satisfied: tqdm>=4.17.1 in /usr/local/lib/python3.12/dist-packages (from textworld==1.6.1) (4.67.1)
# Requirement already satisfied: cffi>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from textworld==1.6.1) (2.0.0)
# Requirement already satisfied: networkx>=2 in /usr/local/lib/python3.12/dist-packages (from textworld==1.6.1) (3.6.1)
# Requirement already satisfied: more_itertools in /usr/local/lib/python3.12/dist-packages (from textworld==1.6.1) (10.8.0)
# Requirement already satisfied: hashids>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from textworld==1.6.1) (1.3.1)
# Requirement already satisfied: jericho>=3.0.3 in /usr/local/lib/python3.12/dist-packages (from textworld==1.6.1) (3.3.1)
# Requirement already satisfied: mementos>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from textworld==1.6.1) (1.3.1)
# Requirement already satisfied: termcolor in /usr/local/lib/python3.12/dist-packages (from textworld==1.6.1) (3.3.0)
# Requirement already satisfied: prompt_toolkit in /usr/local/lib/python3.12/dist-packages (from textworld==1.6.1) (3.0.52)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from gym) (3.1.2)
# Requirement already satisfied: gym-notices>=0.0.4 in /usr/local/lib/python3.12/dist-packages (from gym) (0.1.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch) (3.20.2)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch) (1.14.0)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.12/dist-packages (from torch) (2025.3.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.12/dist-packages (from torchvision) (11.3.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.12/dist-packages (from cffi>=1.0.0->textworld==1.6.1) (2.23)
# Requirement already satisfied: spacy>=2.1.0 in /usr/local/lib/python3.12/dist-packages (from jericho>=3.0.3->textworld==1.6.1) (3.8.11)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch) (3.0.3)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.12/dist-packages (from prompt_toolkit->textworld==1.6.1) (0.2.14)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /usr/local/lib/python3.12/dist-packages (from spacy>=2.1.0->jericho>=3.0.3->textworld==1.6.1) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from spacy>=2.1.0->jericho>=3.0.3->textworld==1.6.1) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.12/dist-packages (from spacy>=2.1.0->jericho>=3.0.3->textworld==1.6.1) (1.0.15)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.12/dist-packages (from spacy>=2.1.0->jericho>=3.0.3->textworld==1.6.1) (2.0.13)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.12/dist-packages (from spacy>=2.1.0->jericho>=3.0.3->textworld==1.6.1) (3.0.12)
# Requirement already satisfied: thinc<8.4.0,>=8.3.4 in /usr/local/lib/python3.12/dist-packages (from spacy>=2.1.0->jericho>=3.0.3->textworld==1.6.1) (8.3.10)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /usr/local/lib/python3.12/dist-packages (from spacy>=2.1.0->jericho>=3.0.3->textworld==1.6.1) (1.1.3)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.12/dist-packages (from spacy>=2.1.0->jericho>=3.0.3->textworld==1.6.1) (2.5.2)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.12/dist-packages (from spacy>=2.1.0->jericho>=3.0.3->textworld==1.6.1) (2.0.10)
# Requirement already satisfied: weasel<0.5.0,>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from spacy>=2.1.0->jericho>=3.0.3->textworld==1.6.1) (0.4.3)
# Requirement already satisfied: typer-slim<1.0.0,>=0.3.0 in /usr/local/lib/python3.12/dist-packages (from spacy>=2.1.0->jericho>=3.0.3->textworld==1.6.1) (0.21.1)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from spacy>=2.1.0->jericho>=3.0.3->textworld==1.6.1) (2.32.4)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /usr/local/lib/python3.12/dist-packages (from spacy>=2.1.0->jericho>=3.0.3->textworld==1.6.1) (2.12.3)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from spacy>=2.1.0->jericho>=3.0.3->textworld==1.6.1) (25.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy>=2.1.0->jericho>=3.0.3->textworld==1.6.1) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.4 in /usr/local/lib/python3.12/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy>=2.1.0->jericho>=3.0.3->textworld==1.6.1) (2.41.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy>=2.1.0->jericho>=3.0.3->textworld==1.6.1) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=2.1.0->jericho>=3.0.3->textworld==1.6.1) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=2.1.0->jericho>=3.0.3->textworld==1.6.1) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=2.1.0->jericho>=3.0.3->textworld==1.6.1) (1.26.20)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=2.1.0->jericho>=3.0.3->textworld==1.6.1) (2026.1.4)
# Requirement already satisfied: blis<1.4.0,>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from thinc<8.4.0,>=8.3.4->spacy>=2.1.0->jericho>=3.0.3->textworld==1.6.1) (1.3.3)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/lib/python3.12/dist-packages (from thinc<8.4.0,>=8.3.4->spacy>=2.1.0->jericho>=3.0.3->textworld==1.6.1) (0.1.5)
# Requirement already satisfied: click>=8.0.0 in /usr/local/lib/python3.12/dist-packages (from typer-slim<1.0.0,>=0.3.0->spacy>=2.1.0->jericho>=3.0.3->textworld==1.6.1) (8.3.1)
# Requirement already satisfied: cloudpathlib<1.0.0,>=0.7.0 in /usr/local/lib/python3.12/dist-packages (from weasel<0.5.0,>=0.4.2->spacy>=2.1.0->jericho>=3.0.3->textworld==1.6.1) (0.23.0)
# Requirement already satisfied: smart-open<8.0.0,>=5.2.1 in /usr/local/lib/python3.12/dist-packages (from weasel<0.5.0,>=0.4.2->spacy>=2.1.0->jericho>=3.0.3->textworld==1.6.1) (7.5.0)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.12/dist-packages (from smart-open<8.0.0,>=5.2.1->weasel<0.5.0,>=0.4.2->spacy>=2.1.0->jericho>=3.0.3->textworld==1.6.1) (2.0.1)

# %%
import os
if not os.path.exists('tw_games'):
    os.makedirs('tw_games')
print("Created directory 'tw_games' if it didn't exist.")
# Out:
# Created directory 'tw_games' if it didn't exist.

# %%
# !tw-make custom --world-size 2 --quest-length 3 --nb-objects 10 --output tw_games/game.ulx -f -v --seed 123
# Out:
# Global seed: 123
# Game generated: /content/tw_games/game.ulx
#
# Objective:
# You are now playing a fast paced round of TextWorld! Here is your task for today. First of all, you could, like, try to travel east. After that, take the binder from the locker. With the binder, place the binder on the mantelpiece. Alright, thanks!
#
# Walkthrough:
# go east > take binder from locker > put binder on mantelpiece
#
# -= Stats =-
# Nb. locations: 2
# Nb. objects: 10

# %%
import textworld.gym
env_id = textworld.gym.register_game('tw_games/game.ulx')
print(env_id)
# Out:
# tw-v0

# %%
env = textworld.gym.make(env_id)
obs, infos = env.reset()
print(obs)
# Out:
#                     ________  ________  __    __  ________
#                    |        \|        \|  \  |  \|        \
#                     \$$$$$$$$| $$$$$$$$| $$  | $$ \$$$$$$$$
#                       | $$   | $$__     \$$\/  $$   | $$
#                       | $$   | $$  \     >$$  $$    | $$
#                       | $$   | $$$$$    /  $$$$\    | $$
#                       | $$   | $$_____ |  $$ \$$\   | $$
#                       | $$   | $$     \| $$  | $$   | $$
#                        \$$    \$$$$$$$$ \$$   \$$    \$$
#               __       __   ______   _______   __        _______
#              |  \  _  |  \ /      \ |       \ |  \      |       \
#              | $$ / \ | $$|  $$$$$$\| $$$$$$$\| $$      | $$$$$$$\
#              | $$/  $\| $$| $$  | $$| $$__| $$| $$      | $$  | $$
#              | $$  $$$\ $$| $$  | $$| $$    $$| $$      | $$  | $$
#              | $$ $$\$$\$$| $$  | $$| $$$$$$$\| $$      | $$  | $$
#              | $$$$  \$$$$| $$__/ $$| $$  | $$| $$_____ | $$__/ $$
#              | $$$    \$$$ \$$    $$| $$  | $$| $$     \| $$    $$
#               \$$      \$$  \$$$$$$  \$$   \$$ \$$$$$$$$ \$$$$$$$
#
# You are now playing a fast paced round of TextWorld! Here is your task for today. First of all, you could, like, try to travel east. After that, take the binder from the locker. With the binder, place the binder on the mantelpiece. Alright, thanks!
#
# -= Vault =-
# You've just walked into a vault. You begin to take stock of what's here.
#
# An open safe is here. What a letdown! The safe is empty! You make out a shelf. But the thing hasn't got anything on it. What, you think everything in TextWorld should have stuff on it?
#
# You don't like doors? Why not try going east, that entranceway is unguarded.

# %%
obs, score, done, infos = env.step("go east")
print(obs)
# Out:
# -= Office =-
# You arrive in an office. An ordinary one.
#
# You can make out a locker. The locker contains a binder. You see a case. The case is empty, what a horrible day! You lean against the wall, inadvertently pressing a secret button. The wall opens up to reveal a mantelpiece. You wonder idly who left that here. The mantelpiece is standard. The mantelpiece appears to be empty. If you haven't noticed it already, there seems to be something there by the wall, it's a table. Unfortunately, there isn't a thing on it. Hm. Oh well
#
# There is an exit to the west. Don't worry, it is unguarded.

# %%
try:
    done = False
    obs, _ = env.reset()
    print(obs)
    nb_moves = 0
    while not done:
        command = input("> ")
        obs, score, done, _ = env.step(command)
        print(obs)
        nb_moves += 1

except KeyboardInterrupt:
    pass  # Press the stop button in the toolbar to quit the game.

print("Played {} steps, scoring {} points.".format(nb_moves, score))
# Out:
#                     ________  ________  __    __  ________
#                    |        \|        \|  \  |  \|        \
#                     \$$$$$$$$| $$$$$$$$| $$  | $$ \$$$$$$$$
#                       | $$   | $$__     \$$\/  $$   | $$
#                       | $$   | $$  \     >$$  $$    | $$
#                       | $$   | $$$$$    /  $$$$\    | $$
#                       | $$   | $$_____ |  $$ \$$\   | $$
#                       | $$   | $$     \| $$  | $$   | $$
#                        \$$    \$$$$$$$$ \$$   \$$    \$$
#               __       __   ______   _______   __        _______
#              |  \  _  |  \ /      \ |       \ |  \      |       \
#              | $$ / \ | $$|  $$$$$$\| $$$$$$$\| $$      | $$$$$$$\
#              | $$/  $\| $$| $$  | $$| $$__| $$| $$      | $$  | $$
#              | $$  $$$\ $$| $$  | $$| $$    $$| $$      | $$  | $$
#              | $$ $$\$$\$$| $$  | $$| $$$$$$$\| $$      | $$  | $$
#              | $$$$  \$$$$| $$__/ $$| $$  | $$| $$_____ | $$__/ $$
#              | $$$    \$$$ \$$    $$| $$  | $$| $$     \| $$    $$
#               \$$      \$$  \$$$$$$  \$$   \$$ \$$$$$$$$ \$$$$$$$
#
# You are now playing a fast paced round of TextWorld! Here is your task for today. First of all, you could, like, try to travel east. After that, take the binder from the locker. With the binder, place the binder on the mantelpiece. Alright, thanks!
#
# -= Vault =-
# You've just walked into a vault. You begin to take stock of what's here.
#
# An open safe is here. What a letdown! The safe is empty! You make out a shelf. But the thing hasn't got anything on it. What, you think everything in TextWorld should have stuff on it?
#
# You don't like doors? Why not try going east, that entranceway is unguarded.
#
# > go east
#
# -= Office =-
# You arrive in an office. An ordinary one.
#
# You can make out a locker. The locker contains a binder. You see a case. The case is empty, what a horrible day! You lean against the wall, inadvertently pressing a secret button. The wall opens up to reveal a mantelpiece. You wonder idly who left that here. The mantelpiece is standard. The mantelpiece appears to be empty. If you haven't noticed it already, there seems to be something there by the wall, it's a table. Unfortunately, there isn't a thing on it. Hm. Oh well
#
# There is an exit to the west. Don't worry, it is unguarded.
#
#
# > take binder
# You take the binder from the locker.
#
#
# > put binder on mantelpiece
# You put the binder on the mantelpiece.
#
#
# Your score has just gone up by one point.
#
#
#                                *** The End ***
#
# You scored 1 out of a possible 1, in 4 turns.
#
#
# Would you like to RESTART, RESTORE a saved game, QUIT or UNDO the last command?
# >
# Played 3 steps, scoring 1 points.

# %%
import textworld

request_infos = textworld.EnvInfos(
    admissible_commands=True,  # All commands relevant to the current state.
    entities=True              # List of all interactable entities found in the game.
)

# Requesting additional information should be done when registering the game.
env_id = textworld.gym.register_game('tw_games/game.ulx', request_infos)
env = textworld.gym.make(env_id)

obs, infos = env.reset()
print("Entities: {}\n".format(infos["entities"]))
print("Admissible commands:\n  {}".format("\n  ".join(infos["admissible_commands"])))
# Out:
# Entities: ['locker', 'case', 'safe', 'mantelpiece', 'table', 'shelf', 'key', 'passkey', 'binder', 'cd', 'north', 'south', 'east', 'west']
#
# Admissible commands:
#   close safe
#   drop cd
#   drop key
#   drop passkey
#   examine cd
#   examine key
#   examine passkey
#   examine safe
#   examine shelf
#   go east
#   insert cd into safe
#   insert key into safe
#   insert passkey into safe
#   inventory
#   look
#   put cd on shelf
#   put key on shelf
#   put passkey on shelf

# %%
import textworld

request_infos = textworld.EnvInfos(
    facts=True  # All the facts that are currently true about the world.
)

# Requesting additional information should be done when registering the game.
env_id = textworld.gym.register_game('tw_games/game.ulx', request_infos)
env = textworld.gym.make(env_id)

obs, infos = env.reset()

print("-= Facts =-")
print("\n".join(map(str, infos["facts"])))
# Out:
# -= Facts =-
# at(P, vault: r)
# at(case: c, office: r)
# at(safe: c, vault: r)
# at(locker: c, office: r)
# at(table: s, office: r)
# at(shelf: s, vault: r)
# at(mantelpiece: s, office: r)
# east_of(office: r, vault: r)
# free(vault: r, office: r)
# free(office: r, vault: r)
# in(passkey: k, I)
# in(key: k, I)
# in(binder: o, locker: c)
# in(cd: o, I)
# match(key: k, locker: c)
# match(passkey: k, safe: c)
# open(safe: c)
# open(case: c)
# open(locker: c)
# west_of(vault: r, office: r)

# %%
obs, _, _, infos = env.step("close safe")
print(obs)

print("-= Facts =-")
print("\n".join(map(str, infos["facts"])))
# Out:
# You close the safe.
#
#
# -= Facts =-
# at(P, vault: r)
# at(case: c, office: r)
# at(safe: c, vault: r)
# at(locker: c, office: r)
# at(table: s, office: r)
# at(shelf: s, vault: r)
# at(mantelpiece: s, office: r)
# east_of(office: r, vault: r)
# free(vault: r, office: r)
# free(office: r, vault: r)
# in(passkey: k, I)
# in(key: k, I)
# in(binder: o, locker: c)
# in(cd: o, I)
# match(key: k, locker: c)
# match(passkey: k, safe: c)
# open(case: c)
# open(locker: c)
# west_of(vault: r, office: r)
# closed(safe: c)

# %%
# !pip install textworld[vis]
# Out:
# Requirement already satisfied: textworld[vis] in /usr/local/lib/python3.12/dist-packages (1.6.1)
# Requirement already satisfied: numpy>=1.14.5 in /usr/local/lib/python3.12/dist-packages (from textworld[vis]) (2.0.2)
# Requirement already satisfied: tqdm>=4.17.1 in /usr/local/lib/python3.12/dist-packages (from textworld[vis]) (4.67.1)
# Requirement already satisfied: cffi>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from textworld[vis]) (2.0.0)
# Requirement already satisfied: networkx>=2 in /usr/local/lib/python3.12/dist-packages (from textworld[vis]) (3.6.1)
# Requirement already satisfied: more_itertools in /usr/local/lib/python3.12/dist-packages (from textworld[vis]) (10.8.0)
# Requirement already satisfied: tatsu>=5.8.3 in /usr/local/lib/python3.12/dist-packages (from textworld[vis]) (5.8.3)
# Requirement already satisfied: hashids>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from textworld[vis]) (1.3.1)
# Requirement already satisfied: jericho>=3.0.3 in /usr/local/lib/python3.12/dist-packages (from textworld[vis]) (3.3.1)
# Requirement already satisfied: mementos>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from textworld[vis]) (1.3.1)
# Requirement already satisfied: termcolor in /usr/local/lib/python3.12/dist-packages (from textworld[vis]) (3.3.0)
# Requirement already satisfied: prompt_toolkit in /usr/local/lib/python3.12/dist-packages (from textworld[vis]) (3.0.52)
# Requirement already satisfied: pybars3>=0.9.3 in /usr/local/lib/python3.12/dist-packages (from textworld[vis]) (0.9.7)
# Requirement already satisfied: flask>=1.0.2 in /usr/local/lib/python3.12/dist-packages (from textworld[vis]) (3.1.2)
# Requirement already satisfied: selenium<4.3,>=3.12.0 in /usr/local/lib/python3.12/dist-packages (from textworld[vis]) (4.2.0)
# Requirement already satisfied: greenlet>=0.4.13 in /usr/local/lib/python3.12/dist-packages (from textworld[vis]) (3.3.0)
# Requirement already satisfied: gevent>=1.3.5 in /usr/local/lib/python3.12/dist-packages (from textworld[vis]) (25.9.1)
# Requirement already satisfied: pillow>=5.1.0 in /usr/local/lib/python3.12/dist-packages (from textworld[vis]) (11.3.0)
# Requirement already satisfied: plotly>=4.0.0 in /usr/local/lib/python3.12/dist-packages (from textworld[vis]) (5.24.1)
# Requirement already satisfied: pydot>=1.2.4 in /usr/local/lib/python3.12/dist-packages (from textworld[vis]) (4.0.1)
# Requirement already satisfied: psutil in /usr/local/lib/python3.12/dist-packages (from textworld[vis]) (5.9.5)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from textworld[vis]) (3.10.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.12/dist-packages (from cffi>=1.0.0->textworld[vis]) (2.23)
# Requirement already satisfied: blinker>=1.9.0 in /usr/local/lib/python3.12/dist-packages (from flask>=1.0.2->textworld[vis]) (1.9.0)
# Requirement already satisfied: click>=8.1.3 in /usr/local/lib/python3.12/dist-packages (from flask>=1.0.2->textworld[vis]) (8.3.1)
# Requirement already satisfied: itsdangerous>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from flask>=1.0.2->textworld[vis]) (2.2.0)
# Requirement already satisfied: jinja2>=3.1.2 in /usr/local/lib/python3.12/dist-packages (from flask>=1.0.2->textworld[vis]) (3.1.6)
# Requirement already satisfied: markupsafe>=2.1.1 in /usr/local/lib/python3.12/dist-packages (from flask>=1.0.2->textworld[vis]) (3.0.3)
# Requirement already satisfied: werkzeug>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from flask>=1.0.2->textworld[vis]) (3.1.5)
# Requirement already satisfied: zope.event in /usr/local/lib/python3.12/dist-packages (from gevent>=1.3.5->textworld[vis]) (6.1)
# Requirement already satisfied: zope.interface in /usr/local/lib/python3.12/dist-packages (from gevent>=1.3.5->textworld[vis]) (8.2)
# Requirement already satisfied: spacy>=2.1.0 in /usr/local/lib/python3.12/dist-packages (from jericho>=3.0.3->textworld[vis]) (3.8.11)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.12/dist-packages (from plotly>=4.0.0->textworld[vis]) (9.1.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from plotly>=4.0.0->textworld[vis]) (25.0)
# Requirement already satisfied: PyMeta3>=0.5.1 in /usr/local/lib/python3.12/dist-packages (from pybars3>=0.9.3->textworld[vis]) (0.5.1)
# Requirement already satisfied: pyparsing>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from pydot>=1.2.4->textworld[vis]) (3.3.1)
# Requirement already satisfied: urllib3~=1.26 in /usr/local/lib/python3.12/dist-packages (from urllib3[secure,socks]~=1.26->selenium<4.3,>=3.12.0->textworld[vis]) (1.26.20)
# Requirement already satisfied: trio~=0.17 in /usr/local/lib/python3.12/dist-packages (from selenium<4.3,>=3.12.0->textworld[vis]) (0.32.0)
# Requirement already satisfied: trio-websocket~=0.9 in /usr/local/lib/python3.12/dist-packages (from selenium<4.3,>=3.12.0->textworld[vis]) (0.12.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->textworld[vis]) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->textworld[vis]) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->textworld[vis]) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->textworld[vis]) (1.4.9)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib->textworld[vis]) (2.9.0.post0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.12/dist-packages (from prompt_toolkit->textworld[vis]) (0.2.14)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib->textworld[vis]) (1.17.0)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /usr/local/lib/python3.12/dist-packages (from spacy>=2.1.0->jericho>=3.0.3->textworld[vis]) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from spacy>=2.1.0->jericho>=3.0.3->textworld[vis]) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.12/dist-packages (from spacy>=2.1.0->jericho>=3.0.3->textworld[vis]) (1.0.15)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.12/dist-packages (from spacy>=2.1.0->jericho>=3.0.3->textworld[vis]) (2.0.13)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.12/dist-packages (from spacy>=2.1.0->jericho>=3.0.3->textworld[vis]) (3.0.12)
# Requirement already satisfied: thinc<8.4.0,>=8.3.4 in /usr/local/lib/python3.12/dist-packages (from spacy>=2.1.0->jericho>=3.0.3->textworld[vis]) (8.3.10)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /usr/local/lib/python3.12/dist-packages (from spacy>=2.1.0->jericho>=3.0.3->textworld[vis]) (1.1.3)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.12/dist-packages (from spacy>=2.1.0->jericho>=3.0.3->textworld[vis]) (2.5.2)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.12/dist-packages (from spacy>=2.1.0->jericho>=3.0.3->textworld[vis]) (2.0.10)
# Requirement already satisfied: weasel<0.5.0,>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from spacy>=2.1.0->jericho>=3.0.3->textworld[vis]) (0.4.3)
# Requirement already satisfied: typer-slim<1.0.0,>=0.3.0 in /usr/local/lib/python3.12/dist-packages (from spacy>=2.1.0->jericho>=3.0.3->textworld[vis]) (0.21.1)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from spacy>=2.1.0->jericho>=3.0.3->textworld[vis]) (2.32.4)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /usr/local/lib/python3.12/dist-packages (from spacy>=2.1.0->jericho>=3.0.3->textworld[vis]) (2.12.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from spacy>=2.1.0->jericho>=3.0.3->textworld[vis]) (75.2.0)
# Requirement already satisfied: attrs>=23.2.0 in /usr/local/lib/python3.12/dist-packages (from trio~=0.17->selenium<4.3,>=3.12.0->textworld[vis]) (25.4.0)
# Requirement already satisfied: sortedcontainers in /usr/local/lib/python3.12/dist-packages (from trio~=0.17->selenium<4.3,>=3.12.0->textworld[vis]) (2.4.0)
# Requirement already satisfied: idna in /usr/local/lib/python3.12/dist-packages (from trio~=0.17->selenium<4.3,>=3.12.0->textworld[vis]) (3.11)
# Requirement already satisfied: outcome in /usr/local/lib/python3.12/dist-packages (from trio~=0.17->selenium<4.3,>=3.12.0->textworld[vis]) (1.3.0.post0)
# Requirement already satisfied: sniffio>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from trio~=0.17->selenium<4.3,>=3.12.0->textworld[vis]) (1.3.1)
# Requirement already satisfied: wsproto>=0.14 in /usr/local/lib/python3.12/dist-packages (from trio-websocket~=0.9->selenium<4.3,>=3.12.0->textworld[vis]) (1.3.2)
# Requirement already satisfied: pyOpenSSL>=0.14 in /usr/local/lib/python3.12/dist-packages (from urllib3[secure,socks]~=1.26->selenium<4.3,>=3.12.0->textworld[vis]) (24.2.1)
# Requirement already satisfied: cryptography>=1.3.4 in /usr/local/lib/python3.12/dist-packages (from urllib3[secure,socks]~=1.26->selenium<4.3,>=3.12.0->textworld[vis]) (43.0.3)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from urllib3[secure,socks]~=1.26->selenium<4.3,>=3.12.0->textworld[vis]) (2026.1.4)
# Requirement already satisfied: urllib3-secure-extra in /usr/local/lib/python3.12/dist-packages (from urllib3[secure,socks]~=1.26->selenium<4.3,>=3.12.0->textworld[vis]) (0.1.0)
# Requirement already satisfied: PySocks!=1.5.7,<2.0,>=1.5.6 in /usr/local/lib/python3.12/dist-packages (from urllib3[secure,socks]~=1.26->selenium<4.3,>=3.12.0->textworld[vis]) (1.7.1)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy>=2.1.0->jericho>=3.0.3->textworld[vis]) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.4 in /usr/local/lib/python3.12/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy>=2.1.0->jericho>=3.0.3->textworld[vis]) (2.41.4)
# Requirement already satisfied: typing-extensions>=4.14.1 in /usr/local/lib/python3.12/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy>=2.1.0->jericho>=3.0.3->textworld[vis]) (4.15.0)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy>=2.1.0->jericho>=3.0.3->textworld[vis]) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=2.1.0->jericho>=3.0.3->textworld[vis]) (3.4.4)
# Requirement already satisfied: blis<1.4.0,>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from thinc<8.4.0,>=8.3.4->spacy>=2.1.0->jericho>=3.0.3->textworld[vis]) (1.3.3)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/lib/python3.12/dist-packages (from thinc<8.4.0,>=8.3.4->spacy>=2.1.0->jericho>=3.0.3->textworld[vis]) (0.1.5)
# Requirement already satisfied: cloudpathlib<1.0.0,>=0.7.0 in /usr/local/lib/python3.12/dist-packages (from weasel<0.5.0,>=0.4.2->spacy>=2.1.0->jericho>=3.0.3->textworld[vis]) (0.23.0)
# Requirement already satisfied: smart-open<8.0.0,>=5.2.1 in /usr/local/lib/python3.12/dist-packages (from weasel<0.5.0,>=0.4.2->spacy>=2.1.0->jericho>=3.0.3->textworld[vis]) (7.5.0)
# Requirement already satisfied: h11<1,>=0.16.0 in /usr/local/lib/python3.12/dist-packages (from wsproto>=0.14->trio-websocket~=0.9->selenium<4.3,>=3.12.0->textworld[vis]) (0.16.0)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.12/dist-packages (from smart-open<8.0.0,>=5.2.1->weasel<0.5.0,>=0.4.2->spacy>=2.1.0->jericho>=3.0.3->textworld[vis]) (2.0.1)

# %%
import textworld.render
textworld.render.show_graph(infos["facts"])
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="d3611db0-f9a9-44bd-8f69-6d7d07e94b24" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d3611db0-f9a9-44bd-8f69-6d7d07e94b24")) {                    Plotly.newPlot(                        "d3611db0-f9a9-44bd-8f69-6d7d07e94b24",                        [{"hoverinfo":"none","line":{"color":"#888","shape":"spline","smoothing":1,"width":0.5},"mode":"lines","x":[154.61,197.09500000000003,239.58,null],"y":[125.08,151.675,178.27,null],"type":"scatter"},{"hoverinfo":"none","line":{"color":"#888","shape":"spline","smoothing":1,"width":0.5},"mode":"lines","x":[239.58,222.15,204.72,null],"y":[178.27,232.115,285.96,null],"type":"scatter"},{"hoverinfo":"none","line":{"color":"#888","shape":"spline","smoothing":1,"width":0.5},"mode":"lines","x":[108.47,156.595,204.72,null],"y":[328.26,307.11,285.96,null],"type":"scatter"},{"hoverinfo":"none","line":{"color":"#888","shape":"spline","smoothing":1,"width":0.5},"mode":"lines","x":[108.47,68.04599999999999,27.622,null],"y":[328.26,306.08,283.9,null],"type":"scatter"},{"hoverinfo":"none","line":{"color":"#888","shape":"spline","smoothing":1,"width":0.5},"mode":"lines","x":[204.72,222.15,239.58,null],"y":[285.96,232.115,178.27,null],"type":"scatter"},{"hoverinfo":"none","line":{"color":"#888","shape":"spline","smoothing":1,"width":0.5},"mode":"lines","x":[223.13,231.35500000000002,239.58,null],"y":[70.913,124.5915,178.27,null],"type":"scatter"},{"hoverinfo":"none","line":{"color":"#888","shape":"spline","smoothing":1,"width":0.5},"mode":"lines","x":[223.13,266.28,309.43,null],"y":[70.913,44.536,18.159,null],"type":"scatter"},{"hoverinfo":"none","line":{"color":"#888","shape":"spline","smoothing":1,"width":0.5},"mode":"lines","x":[211.65,208.185,204.72,null],"y":[331.11,308.53499999999997,285.96,null],"type":"scatter"},{"hoverinfo":"none","line":{"color":"#888","shape":"spline","smoothing":1,"width":0.5},"mode":"lines","x":[211.65,242.26999999999998,272.89,null],"y":[331.11,374.40999999999997,417.71,null],"type":"scatter"},{"hoverinfo":"none","line":{"color":"#888","shape":"spline","smoothing":1,"width":0.5},"mode":"lines","x":[121.66,163.19,204.72,null],"y":[224.21,255.08499999999998,285.96,null],"type":"scatter"},{"hoverinfo":"none","line":{"color":"#888","shape":"spline","smoothing":1,"width":0.5},"mode":"lines","x":[345.69,292.635,239.58,null],"y":[163.82,171.04500000000002,178.27,null],"type":"scatter"},{"hoverinfo":"none","line":{"color":"#888","shape":"spline","smoothing":1,"width":0.5},"mode":"lines","x":[323.52,264.12,204.72,null],"y":[328.96,307.46,285.96,null],"type":"scatter"},{"hoverinfo":"none","line":{"color":"#888","shape":"spline","smoothing":1,"width":0.5},"mode":"lines","x":[294.38,309.845,325.31,null],"y":[119.12,165.41500000000002,211.71,null],"type":"scatter"},{"hoverinfo":"none","line":{"color":"#888","shape":"spline","smoothing":1,"width":0.5},"mode":"lines","x":[294.38,258.755,223.13,null],"y":[119.12,95.01650000000001,70.913,null],"type":"scatter"},{"hoverinfo":"none","line":{"color":"#888","shape":"spline","smoothing":1,"width":0.5},"mode":"lines","x":[277.3,301.305,325.31,null],"y":[269.2,240.45499999999998,211.71,null],"type":"scatter"},{"hoverinfo":"none","line":{"color":"#888","shape":"spline","smoothing":1,"width":0.5},"mode":"lines","x":[277.3,244.47500000000002,211.65,null],"y":[269.2,300.155,331.11,null],"type":"scatter"},{"hoverinfo":"none","line":{"color":"#888","shape":"spline","smoothing":1,"width":0.5},"mode":"lines","x":[159.03,185.34,211.65,null],"y":[424.52,377.815,331.11,null],"type":"scatter"},{"hoverinfo":"none","line":{"color":"#888","shape":"spline","smoothing":1,"width":0.5},"mode":"lines","x":[412.6,368.95500000000004,325.31,null],"y":[236.52,2 ...
