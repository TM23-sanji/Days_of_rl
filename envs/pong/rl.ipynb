# %%
# !uv pip install torch>=2.9.1 wandb>=0.23.0 stable-baselines3>=2.7.0 opencv-python>=4.11.0.86 numpy>=2.3.5 gymnasium>=1.2.2 ale-py>=0.11.2
# Out:
# Using Python 3.12.12 environment at: /usr
# Resolved 64 packages in 462ms
# Prepared 1 package in 21ms
# Installed 1 package in 7ms
#  + stable-baselines3==2.7.1

# %%
import typing as tt, gymnasium as gym, numpy as np, collections
from gymnasium import spaces
from stable_baselines3.common import atari_wrappers

class ImageToPyTorch(gym.ObservationWrapper):
    def __init__(self, env):
        super().__init__(env)
        obs = self.observation_space
        assert isinstance(obs, gym.spaces.Box)
        assert len(obs.shape) == 3
        new_shape = (obs.shape[-1], obs.shape[0], obs.shape[1])
        self.observation_space = gym.spaces.Box(
            low = obs.low.min(), high = obs.high.max(),
            shape=new_shape, dtype=obs.dtype
        )

    def observation(self, observation):
        return np.moveaxis(observation, 2, 0)


class BufferWrapper(gym.ObservationWrapper):
    def __init__(self, env, n_steps):
        super().__init__(env)
        obs = env.observation_space
        assert isinstance(obs, gym.spaces.Box)
        new_obs = gym.spaces.Box(
            obs.low.repeat(n_steps, axis=0), obs.high.repeat(n_steps, axis=0),
            dtype=obs.dtype
        )
        self.observation_space = new_obs
        self.buffer = collections.deque(maxlen=n_steps)

    def reset(self, *, seed: tt.Optional[int] = None, options: tt.Optional[dict[str, tt.Any]] = None):
        for _ in range(self.buffer.maxlen-1):
            self.buffer.append(self.env.observation_space.low)
        obs, extra = self.env.reset()
        return self.observation(obs), extra

    def observation(self, observation: np.ndarray) -> np.ndarray:
        self.buffer.append(observation)
        return np.concatenate(self.buffer)


def make_env(env_name: str, **kwargs):
    env = gym.make(env_name, **kwargs)
    env = atari_wrappers.AtariWrapper(
        env,
        noop_max=30,
        frame_skip=4,        # ← THIS WAS MISSING
        clip_reward=True,    # ← THIS WAS MISSING (or False before)
        terminal_on_life_loss=True
    )
    env = ImageToPyTorch(env)
    env = BufferWrapper(env, n_steps=4)
    return env
# Out:
# Gym has been unmaintained since 2022 and does not support NumPy 2.0 amongst other critical functionality.
# Please upgrade to Gymnasium, the maintained drop-in replacement of Gym, or contact the authors of your software and request that they upgrade.
# See the migration guide at https://gymnasium.farama.org/introduction/migration_guide/ for additional information.
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)

# %%
import gymnasium as gym
import ale_py # Import ale_py for Atari environments
gym.register_envs(ale_py) # Register Atari environments

from stable_baselines3 import DQN

env = make_env('PongNoFrameskip-v4')

# --- DQN Hyperparameters (matching your settings) ---
model = DQN(
    policy="CnnPolicy",
    env=env,
    learning_rate=1e-4,
    buffer_size=10000,           # REPLAY_SIZE
    learning_starts=10000,       # REPLAY_START_SIZE
    batch_size=32,
    gamma=0.99,
    train_freq=1,
    target_update_interval=1000, # SYNC_TARGET_FRAMES
    exploration_fraction=150000 / 1000000,  # ratio of frames for epsilon decay
    exploration_initial_eps=1.0,
    exploration_final_eps=0.01,
    verbose=1,
)


# --- Training ---
model.learn(total_timesteps=1_000_000)


# --- Save the trained model ---
model.save("dqn_pong_sb3")

print("Training complete!")
# Out:
# Using cuda device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 840      |
# |    ep_rew_mean      | -20.8    |
# |    exploration_rate | 0.978    |
# | time/               |          |
# |    episodes         | 4        |
# |    fps              | 593      |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 3360     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 906      |
# |    ep_rew_mean      | -20.2    |
# |    exploration_rate | 0.952    |
# | time/               |          |
# |    episodes         | 8        |
# |    fps              | 641      |
# |    time_elapsed     | 11       |
# |    total_timesteps  | 7250     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 899      |
# |    ep_rew_mean      | -20.2    |
# |    exploration_rate | 0.929    |
# | time/               |          |
# |    episodes         | 12       |
# |    fps              | 510      |
# |    time_elapsed     | 21       |
# |    total_timesteps  | 10788    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000248 |
# |    n_updates        | 787      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 894      |
# |    ep_rew_mean      | -20.2    |
# |    exploration_rate | 0.906    |
# | time/               |          |
# |    episodes         | 16       |
# |    fps              | 318      |
# |    time_elapsed     | 44       |
# |    total_timesteps  | 14306    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000277 |
# |    n_updates        | 4305     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 898      |
# |    ep_rew_mean      | -20.2    |
# |    exploration_rate | 0.882    |
# | time/               |          |
# |    episodes         | 20       |
# |    fps              | 257      |
# |    time_elapsed     | 69       |
# |    total_timesteps  | 17950    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0164   |
# |    n_updates        | 7949     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 908      |
# |    ep_rew_mean      | -20.1    |
# |    exploration_rate | 0.856    |
# | time/               |          |
# |    episodes         | 24       |
# |    fps              | 227      |
# |    time_elapsed     | 95       |
# |    total_timesteps  | 21785    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0149   |
# |    n_updates        | 11784    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 905      |
# |    ep_rew_mean      | -20.1    |
# |    exploration_rate | 0.833    |
# | time/               |          |
# |    episodes         | 28       |
# |    fps              | 210      |
# |    time_elapsed     | 120      |
# |    total_timesteps  | 25341    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000422 |
# |    n_updates        | 15340    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 901      |
# |    ep_rew_mean      | -20.2    |
# |    exploration_rate | 0.81     |
# | time/               |          |
# |    episodes         | 32       |
# |    fps              | 200      |
# |    time_elapsed     | 144      |
# |    total_timesteps  | 28844    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000445 |
# |    n_updates        | 18843    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 910      |
# |    ep_rew_mean      | -20.1    |
# |    exploration_rate | 0.784    |
# | time/               |          |
# |    episodes         | 36       |
# |    fps              | 191      |
# |    time_elapsed     | 170      |
# |    total_timesteps  | 32777    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000981 |
# |    n_updates        | 22776    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 908      |
# |    ep_rew_mean      | -20.2    |
# |    exploration_rate | 0.76     |
# | time/               |          |
# |    episodes         | 40       |
# |    fps              | 185      |
# |    time_elapsed     | 195      |
# |    total_timesteps  | 36304    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000984 |
# |    n_updates        | 26303    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 911      |
# |    ep_rew_mean      | -20.2    |
# |    exploration_rate | 0.735    |
# | time/               |          |
# |    episodes         | 44       |
# |    fps              | 181      |
# |    time_elapsed     | 221      |
# |    total_timesteps  | 40087    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00305  |
# |    n_updates        | 30086    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 923      |
# |    ep_rew_mean      | -20.2    |
# |    exploration_rate | 0.708    |
# | time/               |          |
# |    episodes         | 48       |
# |    fps              | 176      |
# |    time_elapsed     | 250      |
# |    total_timesteps  | 44304    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00404  |
# |    n_updates        | 34303    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 935      |
# |    ep_rew_mean      | -20.1    |
# |    exploration_rate | 0.679    |
# | time/               |          |
# |    episodes         | 52       |
# |    fps              | 173      |
# |    time_elapsed     | 280      |
# |    total_timesteps  | 48642    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00341  |
# |    n_updates        | 38641    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 941      |
# |    ep_rew_mean      | -20.1    |
# |    exploration_rate | 0.652    |
# | time/               |          |
# |    episodes         | 56       |
# |    fps              | 170      |
# |    time_elapsed     | 308      |
# |    total_timesteps  | 52681    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00118  |
# |    n_updates        | 42680    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 951      |
# |    ep_rew_mean      | -20      |
# |    exploration_rate | 0.623    |
# | time/               |          |
# |    episodes         | 60       |
# |    fps              | 167      |
# |    time_elapsed     | 339      |
# |    total_timesteps  | 57080    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00377  |
# |    n_updates        | 47079    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 958      |
# |    ep_rew_mean      | -20      |
# |    exploration_rate | 0.595    |
# | time/               |          |
# |    episodes         | 64       |
# |    fps              | 166      |
# |    time_elapsed     | 369      |
# |    total_timesteps  | 61340    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0178   |
# |    n_updates        | 51339    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 972      |
# |    ep_rew_mean      | -19.9    |
# |    exploration_rate | 0.564    |
# | time/               |          |
# |    episodes         | 68       |
# |    fps              | 164      |
# |    time_elapsed     | 402      |
# |    total_timesteps  | 66096    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00401  |
# |    n_updates        | 56095    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 973      |
# |    ep_rew_mean      | -19.9    |
# |    exploration_rate | 0.538    |
# | time/               |          |
# |    episodes         | 72       |
# |    fps              | 162      |
# |    time_elapsed     | 431      |
# |    total_timesteps  | 70061    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00313  |
# |    n_updates        | 60060    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 989      |
# |    ep_rew_mean      | -19.8    |
# |    exploration_rate | 0.504    |
# | time/               |          |
# |    episodes         | 76       |
# |    fps              | 160      |
# |    time_elapsed     | 467      |
# |    total_timesteps  | 75161    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00326  |
# |    n_updates        | 65160    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 994      |
# |    ep_rew_mean      | -19.8    |
# |    exploration_rate | 0.475    |
# | time/               |          |
# |    episodes         | 80       |
# |    fps              | 159      |
# |    time_elapsed     | 499      |
# |    total_timesteps  | 79555    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0025   |
# |    n_updates        | 69554    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.01e+03 |
# |    ep_rew_mean      | -19.8    |
# |    exploration_rate | 0.437    |
# | time/               |          |
# |    episodes         | 84       |
# |    fps              | 158      |
# |    time_elapsed     | 539      |
# |    total_timesteps  | 85249    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00209  |
# |    n_updates        | 75248    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.02e+03 |
# |    ep_rew_mean      | -19.8    |
# |    exploration_rate | 0.406    |
# | time/               |          |
# |    episodes         | 88       |
# |    fps              | 157      |
# |    time_elapsed     | 572      |
# |    total_timesteps  | 89931    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00362  |
# |    n_updates        | 79930    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.04e+03 |
# |    ep_rew_mean      | -19.7    |
# |    exploration_rate | 0.371    |
# | time/               |          |
# |    episodes         | 92       |
# |    fps              | 156      |
# |    time_elapsed     | 610      |
# |    total_timesteps  | 95233    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00136  |
# |    n_updates        | 85232    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.05e+03 |
# |    ep_rew_mean      | -19.7    |
# |    exploration_rate | 0.336    |
# | time/               |          |
# |    episodes         | 96       |
# |    fps              | 155      |
# |    time_elapsed     | 648      |
# |    total_timesteps  | 100590   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00302  |
# |    n_updates        | 90589    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.07e+03 |
# |    ep_rew_mean      | -19.7    |
# |    exploration_rate | 0.293    |
# | time/               |          |
# |    episodes         | 100      |
# |    fps              | 153      |
# |    time_elapsed     | 695      |
# |    total_timesteps  | 107056   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00279  |
# |    n_updates        | 97055    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.09e+03 |
# |    ep_rew_mean      | -19.5    |
# |    exploration_rate | 0.255    |
# | time/               |          |
# |    episodes         | 104      |
# |    fps              | 153      |
# |    time_elapsed     | 737      |
# |    total_timesteps  | 112845   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00178  |
# |    n_updates        | 102844   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.13e+03 |
# |    ep_rew_mean      | -19.4    |
# |    exploration_rate | 0.207    |
# | time/               |          |
# |    episodes         | 108      |
# |    fps              | 151      |
# |    time_elapsed     | 790      |
# |    total_timesteps  | 120108   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00171  |
# |    n_updates        | 110107   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.16e+03 |
# |    ep_rew_mean      | -19.3    |
# |    exploration_rate | 0.162    |
# | time/               |          |
# |    episodes         | 112      |
# |    fps              | 150      |
# |    time_elapsed     | 840      |
# |    total_timesteps  | 126946   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00505  |
# |    n_updates        | 116945   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.19e+03 |
# |    ep_rew_mean      | -19.2    |
# |    exploration_rate | 0.118    |
# | time/               |          |
# |    episodes         | 116      |
# |    fps              | 150      |
# |    time_elapsed     | 889      |
# |    total_timesteps  | 133575   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00216  |
# |    n_updates        | 123574   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.23e+03 |
# |    ep_rew_mean      | -19.1    |
# |    exploration_rate | 0.0705   |
# | time/               |          |
# |    episodes         | 120      |
# |    fps              | 149      |
# |    time_elapsed     | 944      |
# |    total_timesteps  | 140832   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000854 |
# |    n_updates        | 130831   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.28e+03 |
# |    ep_rew_mean      | -18.9    |
# |    exploration_rate | 0.0108   |
# | time/               |          |
# |    episodes         | 124      |
# |    fps              | 148      |
# |    time_elapsed     | 1011     |
# |    total_timesteps  | 149877   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00309  |
# |    n_updates        | 139876   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.33e+03 |
# |    ep_rew_mean      | -18.7    |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 128      |
# |    fps              | 147      |
# |    time_elapsed     | 1078     |
# |    total_timesteps  | 158833   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00169  |
# |    n_updates        | 148832   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.39e+03 |
# |    ep_rew_mean      | -18.5    |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 132      |
# |    fps              | 146      |
# |    time_elapsed     | 1148     |
# |    total_timesteps  | 168338   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00153  |
# |    n_updates        | 158337   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.45e+03 |
# |    ep_rew_mean      | -18.2    |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 136      |
# |    fps              | 145      |
# |    time_elapsed     | 1217     |
# |    total_timesteps  | 177462   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0013   |
# |    n_updates        | 167461   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.5e+03  |
# |    ep_rew_mean      | -18      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 140      |
# |    fps              | 145      |
# |    time_elapsed     | 1279     |
# |    total_timesteps  | 185817   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00207  |
# |    n_updates        | 175816   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.55e+03 |
# |    ep_rew_mean      | -17.8    |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 144      |
# |    fps              | 144      |
# |    time_elapsed     | 1352     |
# |    total_timesteps  | 195495   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00136  |
# |    n_updates        | 185494   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.62e+03 |
# |    ep_rew_mean      | -17.5    |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 148      |
# |    fps              | 144      |
# |    time_elapsed     | 1432     |
# |    total_timesteps  | 206310   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00114  |
# |    n_updates        | 196309   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.68e+03 |
# |    ep_rew_mean      | -17.3    |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 152      |
# |    fps              | 143      |
# |    time_elapsed     | 1512     |
# |    total_timesteps  | 216906   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00168  |
# |    n_updates        | 206905   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.75e+03 |
# |    ep_rew_mean      | -16.9    |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 156      |
# |    fps              | 142      |
# |    time_elapsed     | 1596     |
# |    total_timesteps  | 228122   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00461  |
# |    n_updates        | 218121   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.8e+03  |
# |    ep_rew_mean      | -16.6    |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 160      |
# |    fps              | 142      |
# |    time_elapsed     | 1666     |
# |    total_timesteps  | 237497   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00244  |
# |    n_updates        | 227496   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.84e+03 |
# |    ep_rew_mean      | -16.4    |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 164      |
# |    fps              | 142      |
# |    time_elapsed     | 1728     |
# |    total_timesteps  | 245770   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00228  |
# |    n_updates        | 235769   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.89e+03 |
# |    ep_rew_mean      | -16.3    |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 168      |
# |    fps              | 141      |
# |    time_elapsed     | 1795     |
# |    total_timesteps  | 254722   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00055  |
# |    n_updates        | 244721   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.94e+03 |
# |    ep_rew_mean      | -16.1    |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 172      |
# |    fps              | 141      |
# |    time_elapsed     | 1865     |
# |    total_timesteps  | 264162   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00755  |
# |    n_updates        | 254161   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.99e+03 |
# |    ep_rew_mean      | -15.8    |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 176      |
# |    fps              | 141      |
# |    time_elapsed     | 1943     |
# |    total_timesteps  | 274660   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00367  |
# |    n_updates        | 264659   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.06e+03 |
# |    ep_rew_mean      | -15.4    |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 180      |
# |    fps              | 141      |
# |    time_elapsed     | 2022     |
# |    total_timesteps  | 285403   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00147  |
# |    n_updates        | 275402   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.12e+03 |
# |    ep_rew_mean      | -14.9    |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 184      |
# |    fps              | 140      |
# |    time_elapsed     | 2111     |
# |    total_timesteps  | 297355   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00136  |
# |    n_updates        | 287354   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.19e+03 |
# |    ep_rew_mean      | -14.5    |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 188      |
# |    fps              | 140      |
# |    time_elapsed     | 2199     |
# |    total_timesteps  | 309111   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00228  |
# |    n_updates        | 299110   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.26e+03 |
# |    ep_rew_mean      | -13.8    |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 192      |
# |    fps              | 140      |
# |    time_elapsed     | 2291     |
# |    total_timesteps  | 321368   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00114  |
# |    n_updates        | 311367   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.33e+03 |
# |    ep_rew_mean      | -13.2    |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 196      |
# |    fps              | 139      |
# |    time_elapsed     | 2380     |
# |    total_timesteps  | 333293   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000871 |
# |    n_updates        | 323292   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.39e+03 |
# |    ep_rew_mean      | -12.3    |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 200      |
# |    fps              | 139      |
# |    time_elapsed     | 2480     |
# |    total_timesteps  | 346545   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00122  |
# |    n_updates        | 336544   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.45e+03 |
# |    ep_rew_mean      | -11.6    |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 204      |
# |    fps              | 139      |
# |    time_elapsed     | 2568     |
# |    total_timesteps  | 358327   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000474 |
# |    n_updates        | 348326   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.5e+03  |
# |    ep_rew_mean      | -10.8    |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 208      |
# |    fps              | 139      |
# |    time_elapsed     | 2657     |
# |    total_timesteps  | 370318   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00148  |
# |    n_updates        | 360317   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.52e+03 |
# |    ep_rew_mean      | -9.55    |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 212      |
# |    fps              | 139      |
# |    time_elapsed     | 2723     |
# |    total_timesteps  | 379244   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000693 |
# |    n_updates        | 369243   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.53e+03 |
# |    ep_rew_mean      | -8.11    |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 216      |
# |    fps              | 139      |
# |    time_elapsed     | 2778     |
# |    total_timesteps  | 386665   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000801 |
# |    n_updates        | 376664   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.54e+03 |
# |    ep_rew_mean      | -6.82    |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 220      |
# |    fps              | 139      |
# |    time_elapsed     | 2841     |
# |    total_timesteps  | 395103   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00107  |
# |    n_updates        | 385102   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.53e+03 |
# |    ep_rew_mean      | -5.61    |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 224      |
# |    fps              | 138      |
# |    time_elapsed     | 2903     |
# |    total_timesteps  | 403342   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000736 |
# |    n_updates        | 393341   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.53e+03 |
# |    ep_rew_mean      | -4.44    |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 228      |
# |    fps              | 138      |
# |    time_elapsed     | 2963     |
# |    total_timesteps  | 411354   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000759 |
# |    n_updates        | 401353   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.51e+03 |
# |    ep_rew_mean      | -3.26    |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 232      |
# |    fps              | 138      |
# |    time_elapsed     | 3024     |
# |    total_timesteps  | 419561   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000492 |
# |    n_updates        | 409560   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.5e+03  |
# |    ep_rew_mean      | -2.11    |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 236      |
# |    fps              | 138      |
# |    time_elapsed     | 3086     |
# |    total_timesteps  | 427815   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00122  |
# |    n_updates        | 417814   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.49e+03 |
# |    ep_rew_mean      | -0.79    |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 240      |
# |    fps              | 138      |
# |    time_elapsed     | 3142     |
# |    total_timesteps  | 435132   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000402 |
# |    n_updates        | 425131   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.47e+03 |
# |    ep_rew_mean      | 0.5      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 244      |
# |    fps              | 138      |
# |    time_elapsed     | 3199     |
# |    total_timesteps  | 442761   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000176 |
# |    n_updates        | 432760   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.45e+03 |
# |    ep_rew_mean      | 1.66     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 248      |
# |    fps              | 138      |
# |    time_elapsed     | 3260     |
# |    total_timesteps  | 450854   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000204 |
# |    n_updates        | 440853   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.42e+03 |
# |    ep_rew_mean      | 2.75     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 252      |
# |    fps              | 138      |
# |    time_elapsed     | 3324     |
# |    total_timesteps  | 459336   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000433 |
# |    n_updates        | 449335   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.4e+03  |
# |    ep_rew_mean      | 3.69     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 256      |
# |    fps              | 138      |
# |    time_elapsed     | 3389     |
# |    total_timesteps  | 467928   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00122  |
# |    n_updates        | 457927   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.38e+03 |
# |    ep_rew_mean      | 4.91     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 260      |
# |    fps              | 137      |
# |    time_elapsed     | 3443     |
# |    total_timesteps  | 475193   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000365 |
# |    n_updates        | 465192   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.38e+03 |
# |    ep_rew_mean      | 6.22     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 264      |
# |    fps              | 137      |
# |    time_elapsed     | 3506     |
# |    total_timesteps  | 483473   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000709 |
# |    n_updates        | 473472   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.37e+03 |
# |    ep_rew_mean      | 7.47     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 268      |
# |    fps              | 137      |
# |    time_elapsed     | 3569     |
# |    total_timesteps  | 491903   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000462 |
# |    n_updates        | 481902   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.35e+03 |
# |    ep_rew_mean      | 8.77     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 272      |
# |    fps              | 137      |
# |    time_elapsed     | 3623     |
# |    total_timesteps  | 499196   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00035  |
# |    n_updates        | 489195   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.32e+03 |
# |    ep_rew_mean      | 9.95     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 276      |
# |    fps              | 137      |
# |    time_elapsed     | 3679     |
# |    total_timesteps  | 506574   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00048  |
# |    n_updates        | 496573   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.28e+03 |
# |    ep_rew_mean      | 11.2     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 280      |
# |    fps              | 137      |
# |    time_elapsed     | 3731     |
# |    total_timesteps  | 513513   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000762 |
# |    n_updates        | 503512   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.24e+03 |
# |    ep_rew_mean      | 12.2     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 284      |
# |    fps              | 137      |
# |    time_elapsed     | 3791     |
# |    total_timesteps  | 521479   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00105  |
# |    n_updates        | 511478   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.19e+03 |
# |    ep_rew_mean      | 13.2     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 288      |
# |    fps              | 137      |
# |    time_elapsed     | 3842     |
# |    total_timesteps  | 528294   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000795 |
# |    n_updates        | 518293   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.14e+03 |
# |    ep_rew_mean      | 14.1     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 292      |
# |    fps              | 137      |
# |    time_elapsed     | 3896     |
# |    total_timesteps  | 535589   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000173 |
# |    n_updates        | 525588   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.1e+03  |
# |    ep_rew_mean      | 14.9     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 296      |
# |    fps              | 137      |
# |    time_elapsed     | 3952     |
# |    total_timesteps  | 542955   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000196 |
# |    n_updates        | 532954   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.04e+03 |
# |    ep_rew_mean      | 15.6     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 300      |
# |    fps              | 137      |
# |    time_elapsed     | 4005     |
# |    total_timesteps  | 550077   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00017  |
# |    n_updates        | 540076   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.99e+03 |
# |    ep_rew_mean      | 16.3     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 304      |
# |    fps              | 137      |
# |    time_elapsed     | 4058     |
# |    total_timesteps  | 557263   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000393 |
# |    n_updates        | 547262   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.94e+03 |
# |    ep_rew_mean      | 16.9     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 308      |
# |    fps              | 137      |
# |    time_elapsed     | 4112     |
# |    total_timesteps  | 564353   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000498 |
# |    n_updates        | 554352   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.92e+03 |
# |    ep_rew_mean      | 17.1     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 312      |
# |    fps              | 137      |
# |    time_elapsed     | 4164     |
# |    total_timesteps  | 571507   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000305 |
# |    n_updates        | 561506   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.92e+03 |
# |    ep_rew_mean      | 17.2     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 316      |
# |    fps              | 137      |
# |    time_elapsed     | 4216     |
# |    total_timesteps  | 578485   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000291 |
# |    n_updates        | 568484   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.91e+03 |
# |    ep_rew_mean      | 17.3     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 320      |
# |    fps              | 137      |
# |    time_elapsed     | 4272     |
# |    total_timesteps  | 585900   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000133 |
# |    n_updates        | 575899   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.9e+03  |
# |    ep_rew_mean      | 17.4     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 324      |
# |    fps              | 137      |
# |    time_elapsed     | 4327     |
# |    total_timesteps  | 593242   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00033  |
# |    n_updates        | 583241   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.89e+03 |
# |    ep_rew_mean      | 17.7     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 328      |
# |    fps              | 137      |
# |    time_elapsed     | 4379     |
# |    total_timesteps  | 600189   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000139 |
# |    n_updates        | 590188   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.88e+03 |
# |    ep_rew_mean      | 17.8     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 332      |
# |    fps              | 136      |
# |    time_elapsed     | 4434     |
# |    total_timesteps  | 607492   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00178  |
# |    n_updates        | 597491   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.86e+03 |
# |    ep_rew_mean      | 18.1     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 336      |
# |    fps              | 136      |
# |    time_elapsed     | 4483     |
# |    total_timesteps  | 614180   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000127 |
# |    n_updates        | 604179   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.86e+03 |
# |    ep_rew_mean      | 18       |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 340      |
# |    fps              | 136      |
# |    time_elapsed     | 4538     |
# |    total_timesteps  | 621546   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000237 |
# |    n_updates        | 611545   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.86e+03 |
# |    ep_rew_mean      | 18.1     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 344      |
# |    fps              | 136      |
# |    time_elapsed     | 4589     |
# |    total_timesteps  | 628374   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000167 |
# |    n_updates        | 618373   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.84e+03 |
# |    ep_rew_mean      | 18.3     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 348      |
# |    fps              | 136      |
# |    time_elapsed     | 4639     |
# |    total_timesteps  | 635133   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000237 |
# |    n_updates        | 625132   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.83e+03 |
# |    ep_rew_mean      | 18.5     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 352      |
# |    fps              | 136      |
# |    time_elapsed     | 4691     |
# |    total_timesteps  | 642088   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000137 |
# |    n_updates        | 632087   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.81e+03 |
# |    ep_rew_mean      | 18.8     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 356      |
# |    fps              | 136      |
# |    time_elapsed     | 4741     |
# |    total_timesteps  | 648911   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000223 |
# |    n_updates        | 638910   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.81e+03 |
# |    ep_rew_mean      | 18.8     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 360      |
# |    fps              | 136      |
# |    time_elapsed     | 4795     |
# |    total_timesteps  | 656103   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000467 |
# |    n_updates        | 646102   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.8e+03  |
# |    ep_rew_mean      | 18.9     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 364      |
# |    fps              | 136      |
# |    time_elapsed     | 4849     |
# |    total_timesteps  | 663117   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000286 |
# |    n_updates        | 653116   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.78e+03 |
# |    ep_rew_mean      | 19.1     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 368      |
# |    fps              | 136      |
# |    time_elapsed     | 4899     |
# |    total_timesteps  | 669858   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000113 |
# |    n_updates        | 659857   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.77e+03 |
# |    ep_rew_mean      | 19.1     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 372      |
# |    fps              | 136      |
# |    time_elapsed     | 4950     |
# |    total_timesteps  | 676692   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000117 |
# |    n_updates        | 666691   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.77e+03 |
# |    ep_rew_mean      | 19.1     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 376      |
# |    fps              | 136      |
# |    time_elapsed     | 5003     |
# |    total_timesteps  | 683925   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000177 |
# |    n_updates        | 673924   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.78e+03 |
# |    ep_rew_mean      | 18.8     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 380      |
# |    fps              | 136      |
# |    time_elapsed     | 5056     |
# |    total_timesteps  | 691025   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00195  |
# |    n_updates        | 681024   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.76e+03 |
# |    ep_rew_mean      | 19       |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 384      |
# |    fps              | 136      |
# |    time_elapsed     | 5108     |
# |    total_timesteps  | 697741   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000242 |
# |    n_updates        | 687740   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.76e+03 |
# |    ep_rew_mean      | 19       |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 388      |
# |    fps              | 136      |
# |    time_elapsed     | 5159     |
# |    total_timesteps  | 704553   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000123 |
# |    n_updates        | 694552   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.76e+03 |
# |    ep_rew_mean      | 19.1     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 392      |
# |    fps              | 136      |
# |    time_elapsed     | 5209     |
# |    total_timesteps  | 711146   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00139  |
# |    n_updates        | 701145   |
# ----------------------------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-3264420565.py in <cell line: 0>()
#      26
#      27 # --- Training ---
# ---> 28 model.learn(total_timesteps=1_000_000)
#      29
#      30
#
# /usr/local/lib/python3.12/dist-packages/stable_baselines3/dqn/dqn.py in learn(self, total_timesteps, callback, log_interval, tb_log_name, reset_num_timesteps, progress_bar)
#     270         progress_bar: bool = False,
#     271     ) -> SelfDQN:
# --> 272         return super().learn(
#     273             total_timesteps=total_timesteps,
#     274             callback=callback,
#
# /usr/local/lib/python3.12/dist-packages/stable_baselines3/common/off_policy_algorithm.py in learn(self, total_timesteps, callback, log_interval, tb_log_name, reset_num_timesteps, progress_bar)
#     352                 # Special case when the user passes `gradient_steps=0`
#     353                 if gradient_steps > 0:
# --> 354                     self.train(batch_size=self.batch_size, gradient_steps=gradient_steps)
#     355
#     356         callback.on_training_end()
#
# /usr/local/lib/python3.12/dist-packages/stable_baselines3/dqn/dqn.py in train(self, gradient_steps, batch_size)
#     220             # Optimize the policy
#     221             self.policy.optimizer.zero_grad()
# --> 222             loss.backward()
#     223             # Clip gradient norm
#     224             th.nn.utils.clip_grad_norm_(self.policy.parameters(), self.max_grad_norm)
#
# /usr/local/lib/python3.12/dist-packages/torch/_tensor.py in backward(self, gradient, retain_graph, create_graph, inputs)
#     623                 inputs=inputs,
#     624             )
# --> 625         torch.autograd.backward(
#     626             self, gradient, retain_graph, create_graph, inputs=inputs
#     627         )
#
# /usr/local/lib/python3.12/dist-packages/torch/autograd/__init__.py in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     345
#     346     grad_tensors_ = _tensor_or_tensors_to_tuple(grad_tensors, len(tensors))
# --> 347     grad_tensors_ = _make_grads(tensors, grad_tensors_, is_grads_batched=False)
#     348     if retain_graph is None:
#     349         retain_graph = create_graph
#
# /usr/local/lib/python3.12/dist-packages/torch/autograd/__init__.py in _make_grads(outputs, grads, is_grads_batched)
#      87
#      88
# ---> 89 def _make_grads(
#      90     outputs: Union[Sequence[torch.Tensor], Sequence[graph.GradientEdge]],
#      91     grads: Sequence[_OptionalTensor],
#
# KeyboardInterrupt:

# %%
model.save("dqn_pong_sb3")

# %%
import gymnasium as gym
from stable_baselines3 import DQN
from stable_baselines3.common.atari_wrappers import (
    NoopResetEnv, MaxAndSkipEnv, EpisodicLifeEnv,
    ClipRewardEnv, WarpFrame
)
from gymnasium.wrappers import RecordVideo
import os

video_dir = "/content/videos"
os.makedirs(video_dir, exist_ok=True)

env = make_env('PongNoFrameskip-v4', render_mode="rgb_array")
env = RecordVideo(env, video_folder=video_dir, name_prefix="dqn_pong")

# Load the trained model
model = DQN.load("dqn_pong_sb3.zip", device="cpu")

# Where to save videos (Colab)

# Create wrapped env WITH recording

# Run one full episode
obs, _ = env.reset()
done = False
total_reward = 0

while not done:
    action, _ = model.predict(obs, deterministic=True)
    obs, reward, terminated, truncated, _ = env.step(action)
    total_reward += reward
    done = terminated or truncated

env.close()
print("Episode reward:", total_reward)
print("Video saved to:", video_dir)
# Out:
# /usr/local/lib/python3.12/dist-packages/gymnasium/wrappers/rendering.py:434: UserWarning: WARN: Unable to save last video! Did you call close()?
#   logger.warn("Unable to save last video! Did you call close()?")
# /usr/local/lib/python3.12/dist-packages/gymnasium/wrappers/rendering.py:293: UserWarning: WARN: Overwriting existing videos at /content/videos folder (try specifying a different `video_folder` for the `RecordVideo` wrapper if this is not desired)
#   logger.warn(
# Episode reward: 21.0
# Video saved to: /content/videos
