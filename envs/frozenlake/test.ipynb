# %%
# !uv pip install torch
# Out:
# Using Python 3.12.12 environment at: /usr
# Audited 1 package in 295ms

# %%
import torch, gymnasium as gym

# %%
env = gym.make('FrozenLake-v1')
print(env.observation_space)
env.action_space.n
# Out:
# Discrete(16)
# np.int64(4)
